# %% [markdown]
# # Preprocess recordings
#
# Notebook within the chronic ephys processing pipeline
# - **1-sglx_preprocess / 1-oe_preprocess**
# - 2-curate_bouts
# - 3-run_sorts
# - 4-curate_sorts
# - 5-...
#
# Use the environment ... to run this notebook
#
# (currently using environment spikesort)

# %%
import sys
sys.path.append('/mnt/cube/lo/envs/ceciestunepipe')
from ceciestunepipe.file import bcistructure as et
from ceciestunepipe.util.sound import boutsearch as bs
from ceciestunepipe.pipeline import searchbout as sb
from ceciestunepipe.tsm import preproc_oe
from ceciestunepipe.tsm import preproc_sglx
# Out:
# /mnt/cube/lo/envs/spikesort/lib/python3.8/site-packages/spikeextractors/__init__.py:21: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if StrictVersion(h5py.__version__) > '2.10.0':
# 2023-09-08 17:30:19,558 root         INFO     Running on pakhi.ucsd.edu
# 2023-09-08 17:30:19,558 root         INFO     Running on pakhi.ucsd.edu
# h5py version > 2.10.0. Some extractors might not work properly. It is recommended to downgrade to version 2.10.0:
# >>> pip install h5py==2.10.0

# %%
force_redo = True
n_jobs = 1 # for deriving bout info
hparams = { # default bout detection parameters that work well for starling
    # spectrogram
    'num_freq':1024, #1024# how many channels to use in a spectrogram #
    'preemphasis':0.97, 
    'frame_shift_ms':5, # step size for fft
    'frame_length_ms':10, #128 # frame length for fft FRAME SAMPLES < NUM_FREQ!!!
    'min_level_db':-55, # minimum threshold db for computing spe 
    'ref_level_db':110, # reference db for computing spec
    'sample_rate':None, # sample rate of your data
    # spectrograms
    'mel_filter': False, # should a mel filter be used?
    'num_mels':1024, # how many channels to use in the mel-spectrogram
    'fmin': 500, # low frequency cutoff for mel filter
    'fmax': 12000, # high frequency cutoff for mel filter
    # spectrogram inversion
    'max_iters':200,
    'griffin_lim_iters':20,
    'power':1.5,
    # Added for the searching
    'read_wav_fun': bs.read_npy_chan, # function for loading the wav_like_stream (has to returns fs, ndarray)
    'file_order_fun': bs.sess_file_id, # function for extracting the file id within the session
    'min_segment': 30, # Minimum length of supra_threshold to consider a 'syllable' (ms)
    'min_silence': 3000, # Minmum distance between groups of syllables to consider separate bouts (ms)
    'min_bout': 3000, # min bout duration (ms)   ##### for finches, make 1000?
    'peak_thresh_rms': 0.55, # threshold (rms) for peak acceptance,
    'thresh_rms': 0.25, # threshold for detection of syllables
    'mean_syl_rms_thresh': 0.3, #threshold for acceptance of mean rms across the syllable (relative to rms of the file)
    'max_bout': 180000, #exclude bouts too long   ##### finch song would never be this long, but fine?
    'l_p_r_thresh': 100, # threshold for n of len_ms/peaks (typycally about 2-3 syllable spans
    'waveform_edges': 1000, #get number of ms before and after the edges of the bout for the waveform sample   ##### Zeke had previously set to 200ms, but fine with this
    'bout_auto_file': 'bout_auto.pickle', # extension for saving the auto found files
    'bout_curated_file': 'bout_checked.pickle', #extension for manually curated files (coming soon)
    }

# %%
# dictionaries for birds / recordings
bird_rec_dict = {
    # Zeke/Pablo had 3 successful finch recordings in the past: z_w12m7_20, z_r12r13_21, z_y19o20_21
#     'z_w12m7_20':[
#         {'sess_par_list':['2020-11-04','2020-11-05','2020-11-06'], # sessions with this configuration
#          'mic_list':['microphone_0'], # list of mics of interest, by signal name in rig.json
#          'adc_list':[], # list of adc channels of interest
#          'stim_list':[], # list of adc chans with the stimulus
#          'nidq_ttl_list':[], # list of TTL signals form the nidq digital inputs to extract (besides the 'sync')
#          'sort':0, # sort index
#          'software':'sglx' # sglx or oe
#         }],
#     'z_r12r13_21':[
#         {'sess_par_list':['2021-06-24','2021-06-25','2021-06-26','2021-06-27','2021-06-28','2021-06-29','2021-06-30','2021-07-01'], # sessions with this configuration
#          'mic_list':['microphone_0'], # list of mics of interest, by signal name in rig.json
#          'adc_list':[], # list of adc channels of interest
#          'stim_list':[], # list of adc chans with the stimulus
#          'nidq_ttl_list': [], # list of TTL signals form the nidq digital inputs to extract (besides the 'sync')
#          'sort':0, # sort index
#          'software':'sglx' # sglx or oe
#         }], 
#     'z_y19o20_21':[   # two implants, 10/26-27 and 12/21-23, with same rig.json info (just different probe serial #)
#         {'sess_par_list':['2021-10-26','2021-10-27','2021-12-21','2021-12-22','2021-12-23'], # sessions with this configuration
#          'probes':['probe_0'],
#          'mic_list':['microphone_1'], # list of mics of interest, by signal name in rig.json
#          'adc_list':[], # list of adc channels of interest
#          'stim_list':[], # list of adc chans with the stimulus
#          'nidq_ttl_list':[], # list of TTL signals form the nidq digital inputs to extract (besides the 'sync')
#          'sort':0, # sort index
#          'software':'sglx' # sglx or oe
#         }],
    # Pablo and I also collected another finch's data: z_c5o30_23
    'z_c5o30_23':[
        {'sess_par_list':['2023-06-12','2023-06-13','2023-06-14','2023-06-15','2023-06-16'], # sessions with this configuration
         'mic_list':['microphone_0'], # list of mics of interest, by signal name in rig.json
         'adc_list':[], # list of adc channels of interest
         'stim_list':[], # list of adc chans with the stimulus
         'nidq_ttl_list':[], # list of TTL signals form the nidq digital inputs to extract (besides the 'sync')
         'sort':0, # sort index
         'software':'sglx' # sglx or oe
        }]
}

# %%
# %%time
# npy method more efficient than wav
mic_file_ext = 'npy'
# loop through all birds / recordings
for this_bird in bird_rec_dict.keys():
    # get session parameters
    sess_par_all = bird_rec_dict[this_bird]
    # get all sessions
    all_bird_sess = et.list_sessions(this_bird)
    # loop through sessions
    for this_sess in all_bird_sess:
        
        # loop though possible session parameter sets
        sess_par_match = []
        for this_sess_par in sess_par_all:
            # save if there is a match
            if this_sess in this_sess_par['sess_par_list']:
                sess_par_match.append(this_sess_par)
                
        # ensure only one match
        if len(sess_par_match) == 1:
            sess_par = sess_par_match[0]
            print(sess_par)
            # add bird and sess variables
            sess_par['bird'] = this_bird        
            sess_par['sess'] = this_sess
            
            # run preproc
            print(this_bird,this_sess,sess_par['software'],'preprocessing session..')
            if sess_par['software'] == 'sglx':
                preproc_sglx.preprocess_session(sess_par,force_redo=force_redo)
            elif sess_par['software'] == 'oe':
                preproc_oe.preprocess_session(sess_par,force_redo=force_redo)
            else:
                print(sess_par['software'],'not implemented..')
                
            # derive bout information
            print(this_bird,this_sess,'deriving bout information..')
            sess_bout_pd = sb.get_all_day_bouts(sess_par,hparams,n_jobs=n_jobs,ephys_software=sess_par['software'],file_ext=mic_file_ext)                
            sb.save_auto_bouts(sess_bout_pd,sess_par,hparams,software=sess_par['software'])
        
        else:
            print(this_bird,this_sess,'session param matches:',len(sess_par_match))
# Out:
# 2023-09-08 16:19:51,527 root         INFO     pre-process all runs of sess 2023-06-12
# 2023-09-08 16:19:51,527 root         INFO     pre-process all runs of sess 2023-06-12
# 2023-09-08 16:19:51,530 ceciestunepipe.file.bcistructure INFO     {'folders': {'bird': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23', 'raw': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23/2023-06-12', 'sglx': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23/2023-06-12/sglx', 'kwik': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-12', 'processed': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-12/sglx', 'derived': '/mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx', 'tmp': '/scratch/chronic_ephys/tmp', 'msort': '/scratch/chronic_ephys/z_c5o30_23/sglx/msort/2023-06-12', 'ksort': '/scratch/chronic_ephys/z_c5o30_23/sglx/ksort/2023-06-12/0', 'sort': '/mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/0'}, 'files': {'par': '/scratch/chronic_ephys/z_c5o30_23/sglx/ksort/2023-06-12/0/params.json', 'set': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23/2023-06-12/sglx/settings.isf', 'rig': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23/2023-06-12/sglx/rig.json', 'kwd': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-12/stream.kwd', 'kwik': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-12/sort_0/spikes.kwik', 'kwe': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-12/events.kwe', 'dat_mic': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-12/sglx/dat_mic.mat', 'dat_ap': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-12/sglx/dat_ap.mat', 'allevents': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-12/sglx/dat_all.pkl', 'wav_mic': '/mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/wav_mic.wav', 'mda_raw': '/scratch/chronic_ephys/z_c5o30_23/sglx/msort/2023-06-12/raw.mda', 'bin_raw': '/scratch/chronic_ephys/z_c5o30_23/sglx/ksort/2023-06-12/0/raw.bin'}}
# 2023-09-08 16:19:51,530 ceciestunepipe.file.bcistructure INFO     {'folders': {'bird': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23', 'raw': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23/2023-06-12', 'sglx': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23/2023-06-12/sglx', 'kwik': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-12', 'processed': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-12/sglx', 'derived': '/mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx', 'tmp': '/scratch/chronic_ephys/tmp', 'msort': '/scratch/chronic_ephys/z_c5o30_23/sglx/msort/2023-06-12', 'ksort': '/scratch/chronic_ephys/z_c5o30_23/sglx/ksort/2023-06-12/0', 'sort': '/mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/0'}, 'files': {'par': '/scratch/chronic_ephys/z_c5o30_23/sglx/ksort/2023-06-12/0/params.json', 'set': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23/2023-06-12/sglx/settings.isf', 'rig': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23/2023-06-12/sglx/rig.json', 'kwd': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-12/stream.kwd', 'kwik': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-12/sort_0/spikes.kwik', 'kwe': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-12/events.kwe', 'dat_mic': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-12/sglx/dat_mic.mat', 'dat_ap': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-12/sglx/dat_ap.mat', 'allevents': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-12/sglx/dat_all.pkl', 'wav_mic': '/mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/wav_mic.wav', 'mda_raw': '/scratch/chronic_ephys/z_c5o30_23/sglx/msort/2023-06-12/raw.mda', 'bin_raw': '/scratch/chronic_ephys/z_c5o30_23/sglx/ksort/2023-06-12/0/raw.bin'}}
# 2023-09-08 16:19:51,535 root         INFO     found epochs: ['1752_g0', '1800_g0']
# 2023-09-08 16:19:51,535 root         INFO     found epochs: ['1752_g0', '1800_g0']
# 2023-09-08 16:19:51,536 ceciestunepipe.util.spikeextractors.preprocess INFO     PREPROCESSING sess 2023-06-12 | epoch 1752_g0
# 2023-09-08 16:19:51,536 ceciestunepipe.util.spikeextractors.preprocess INFO     PREPROCESSING sess 2023-06-12 | epoch 1752_g0
# 2023-09-08 16:19:51,537 ceciestunepipe.util.spikeextractors.preprocess INFO     getting extractors
# 2023-09-08 16:19:51,537 ceciestunepipe.util.spikeextractors.preprocess INFO     getting extractors
# z_c5o30_23 2023-03-24 session param matches: 0
# z_c5o30_23 2023-03-25 session param matches: 0
# z_c5o30_23 2023-03-26 session param matches: 0
# z_c5o30_23 2023-03-27 session param matches: 0
# z_c5o30_23 2023-03-28 session param matches: 0
# z_c5o30_23 2023-03-29 session param matches: 0
# z_c5o30_23 2023-03-30 session param matches: 0
# z_c5o30_23 2023-03-31 session param matches: 0
# z_c5o30_23 2023-04-01 session param matches: 0
# z_c5o30_23 2023-04-02 session param matches: 0
# z_c5o30_23 2023-04-03 session param matches: 0
# z_c5o30_23 2023-04-04 session param matches: 0
# z_c5o30_23 2023-04-05 session param matches: 0
# z_c5o30_23 2023-04-06 session param matches: 0
# z_c5o30_23 2023-04-07 session param matches: 0
# z_c5o30_23 2023-04-08 session param matches: 0
# z_c5o30_23 2023-04-09 session param matches: 0
# z_c5o30_23 2023-04-10 session param matches: 0
# z_c5o30_23 2023-06-02 session param matches: 0
# z_c5o30_23 2023-06-03 session param matches: 0
# z_c5o30_23 2023-06-04 session param matches: 0
# z_c5o30_23 2023-06-05 session param matches: 0
# z_c5o30_23 2023-06-06 session param matches: 0
# z_c5o30_23 2023-06-07 session param matches: 0
# z_c5o30_23 2023-06-08 session param matches: 0
# z_c5o30_23 2023-06-09 session param matches: 0
# z_c5o30_23 2023-06-10 session param matches: 0
# z_c5o30_23 2023-06-11 session param matches: 0
# {'sess_par_list': ['2023-06-12', '2023-06-13', '2023-06-14', '2023-06-15', '2023-06-16'], 'mic_list': ['microphone_0'], 'adc_list': [], 'stim_list': [], 'nidq_ttl_list': [], 'sort': 0, 'software': 'sglx'}
# z_c5o30_23 2023-06-12 sglx preprocessing session..
# preprocessing..
# 2023-09-08 16:19:51,695 ceciestunepipe.util.spikeextractors.preprocess INFO     Got sglx recordings for keys ['nidq', 'lf_0', 'ap_0']
# 2023-09-08 16:19:51,695 ceciestunepipe.util.spikeextractors.preprocess INFO     Got sglx recordings for keys ['nidq', 'lf_0', 'ap_0']
# 2023-09-08 16:19:51,696 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting microphone channel(s) ['microphone_0']
# 2023-09-08 16:19:51,696 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting microphone channel(s) ['microphone_0']
# /mnt/cube/lo/envs/spikesort/lib/python3.8/site-packages/spikeextractors/extraction_tools.py:877: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if isinstance(start_frame, (float, np.float)):
# /mnt/cube/lo/envs/spikesort/lib/python3.8/site-packages/spikeextractors/extraction_tools.py:883: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if isinstance(end_frame, (float, np.float)):
# 2023-09-08 16:19:51,714 ceciestunepipe.util.wavutil INFO     sampling rate 40000
# 2023-09-08 16:19:51,714 ceciestunepipe.util.wavutil INFO     sampling rate 40000
# 2023-09-08 16:19:51,715 ceciestunepipe.util.wavutil INFO     saving (1, 17364865)-shaped array as wav in /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1752_g0/wav_mic.wav
# 2023-09-08 16:19:51,715 ceciestunepipe.util.wavutil INFO     saving (1, 17364865)-shaped array as wav in /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1752_g0/wav_mic.wav
# 2023-09-08 16:19:51,734 ceciestunepipe.util.wavutil INFO     Not saving the file as wav, going straight to numpy + dict
# 2023-09-08 16:19:51,734 ceciestunepipe.util.wavutil INFO     Not saving the file as wav, going straight to numpy + dict
# 2023-09-08 16:19:51,735 ceciestunepipe.util.wavutil INFO     saving (1, 17364865)-shaped array as npy in /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1752_g0/wav_mic.npy
# 2023-09-08 16:19:51,735 ceciestunepipe.util.wavutil INFO     saving (1, 17364865)-shaped array as npy in /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1752_g0/wav_mic.npy
# 2023-09-08 16:19:51,736 ceciestunepipe.util.wavutil INFO     saving (17364865, 1)-shaped array as npy in /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1752_g0/wav_mic.npy
# 2023-09-08 16:19:51,736 ceciestunepipe.util.wavutil INFO     saving (17364865, 1)-shaped array as npy in /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1752_g0/wav_mic.npy
# 2023-09-08 16:19:53,059 ceciestunepipe.util.wavutil INFO     Saving meta of npy array to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1752_g0/wav_mic-npy_meta.json
# 2023-09-08 16:19:53,059 ceciestunepipe.util.wavutil INFO     Saving meta of npy array to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1752_g0/wav_mic-npy_meta.json
# 2023-09-08 16:19:53,062 ceciestunepipe.util.wavutil INFO     Saving meta of npy array to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1752_g0/wav_mic-npy_meta.pickle
# 2023-09-08 16:19:53,062 ceciestunepipe.util.wavutil INFO     Saving meta of npy array to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1752_g0/wav_mic-npy_meta.pickle
# 2023-09-08 16:19:53,064 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting adc channel(s) []
# 2023-09-08 16:19:53,064 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting adc channel(s) []
# /mnt/cube/lo/envs/spikesort/lib/python3.8/site-packages/spikeextractors/extraction_tools.py:877: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if isinstance(start_frame, (float, np.float)):
# /mnt/cube/lo/envs/spikesort/lib/python3.8/site-packages/spikeextractors/extraction_tools.py:883: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if isinstance(end_frame, (float, np.float)):
# /mnt/cube/tsmcpher/code/ceciestunepipe/tsm/preproc_sglx.py:45: UserWarning: Error in epoch 1752_g0
#   warnings.warn('Error in epoch {}'.format(epoch), UserWarning)
# 2023-09-08 16:19:53,067 root         INFO     <function format_exc at 0x7f36b5868280>
# 2023-09-08 16:19:53,067 root         INFO     <function format_exc at 0x7f36b5868280>
# 2023-09-08 16:19:53,068 root         INFO     index 0 is out of bounds for axis 0 with size 0
# 2023-09-08 16:19:53,068 root         INFO     index 0 is out of bounds for axis 0 with size 0
# 2023-09-08 16:19:53,069 root         INFO     Session 2023-06-12 epoch 1752_g0 could not be preprocessed
# 2023-09-08 16:19:53,069 root         INFO     Session 2023-06-12 epoch 1752_g0 could not be preprocessed
# 2023-09-08 16:19:53,079 ceciestunepipe.util.spikeextractors.preprocess INFO     PREPROCESSING sess 2023-06-12 | epoch 1800_g0
# 2023-09-08 16:19:53,079 ceciestunepipe.util.spikeextractors.preprocess INFO     PREPROCESSING sess 2023-06-12 | epoch 1800_g0
# 2023-09-08 16:19:53,080 ceciestunepipe.util.spikeextractors.preprocess INFO     getting extractors
# 2023-09-08 16:19:53,080 ceciestunepipe.util.spikeextractors.preprocess INFO     getting extractors
# 2023-09-08 16:19:53,228 ceciestunepipe.util.spikeextractors.preprocess INFO     Got sglx recordings for keys ['nidq', 'lf_0', 'ap_0']
# 2023-09-08 16:19:53,228 ceciestunepipe.util.spikeextractors.preprocess INFO     Got sglx recordings for keys ['nidq', 'lf_0', 'ap_0']
# 2023-09-08 16:19:53,230 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting microphone channel(s) ['microphone_0']
# 2023-09-08 16:19:53,230 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting microphone channel(s) ['microphone_0']
# /mnt/cube/lo/envs/spikesort/lib/python3.8/site-packages/spikeextractors/extraction_tools.py:877: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if isinstance(start_frame, (float, np.float)):
# /mnt/cube/lo/envs/spikesort/lib/python3.8/site-packages/spikeextractors/extraction_tools.py:883: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if isinstance(end_frame, (float, np.float)):
# 2023-09-08 16:19:53,231 ceciestunepipe.util.wavutil INFO     sampling rate 40000
# 2023-09-08 16:19:53,231 ceciestunepipe.util.wavutil INFO     sampling rate 40000
# 2023-09-08 16:19:53,232 ceciestunepipe.util.wavutil INFO     saving (1, 133735937)-shaped array as wav in /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1800_g0/wav_mic.wav
# 2023-09-08 16:19:53,232 ceciestunepipe.util.wavutil INFO     saving (1, 133735937)-shaped array as wav in /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1800_g0/wav_mic.wav
# 2023-09-08 16:19:53,235 ceciestunepipe.util.wavutil INFO     Not saving the file as wav, going straight to numpy + dict
# 2023-09-08 16:19:53,235 ceciestunepipe.util.wavutil INFO     Not saving the file as wav, going straight to numpy + dict
# 2023-09-08 16:19:53,236 ceciestunepipe.util.wavutil INFO     saving (1, 133735937)-shaped array as npy in /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1800_g0/wav_mic.npy
# 2023-09-08 16:19:53,236 ceciestunepipe.util.wavutil INFO     saving (1, 133735937)-shaped array as npy in /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1800_g0/wav_mic.npy
# 2023-09-08 16:19:53,237 ceciestunepipe.util.wavutil INFO     saving (133735937, 1)-shaped array as npy in /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1800_g0/wav_mic.npy
# 2023-09-08 16:19:53,237 ceciestunepipe.util.wavutil INFO     saving (133735937, 1)-shaped array as npy in /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1800_g0/wav_mic.npy
# 2023-09-08 16:20:01,929 ceciestunepipe.util.wavutil INFO     Saving meta of npy array to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1800_g0/wav_mic-npy_meta.json
# 2023-09-08 16:20:01,929 ceciestunepipe.util.wavutil INFO     Saving meta of npy array to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1800_g0/wav_mic-npy_meta.json
# 2023-09-08 16:20:01,936 ceciestunepipe.util.wavutil INFO     Saving meta of npy array to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1800_g0/wav_mic-npy_meta.pickle
# 2023-09-08 16:20:01,936 ceciestunepipe.util.wavutil INFO     Saving meta of npy array to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1800_g0/wav_mic-npy_meta.pickle
# 2023-09-08 16:20:01,938 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting adc channel(s) []
# 2023-09-08 16:20:01,938 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting adc channel(s) []
# /mnt/cube/lo/envs/spikesort/lib/python3.8/site-packages/spikeextractors/extraction_tools.py:877: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if isinstance(start_frame, (float, np.float)):
# /mnt/cube/lo/envs/spikesort/lib/python3.8/site-packages/spikeextractors/extraction_tools.py:883: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if isinstance(end_frame, (float, np.float)):
# /mnt/cube/tsmcpher/code/ceciestunepipe/tsm/preproc_sglx.py:45: UserWarning: Error in epoch 1800_g0
#   warnings.warn('Error in epoch {}'.format(epoch), UserWarning)
# 2023-09-08 16:20:01,940 root         INFO     <function format_exc at 0x7f36b5868280>
# 2023-09-08 16:20:01,940 root         INFO     <function format_exc at 0x7f36b5868280>
# 2023-09-08 16:20:01,941 root         INFO     index 0 is out of bounds for axis 0 with size 0
# 2023-09-08 16:20:01,941 root         INFO     index 0 is out of bounds for axis 0 with size 0
# 2023-09-08 16:20:01,942 root         INFO     Session 2023-06-12 epoch 1800_g0 could not be preprocessed
# 2023-09-08 16:20:01,942 root         INFO     Session 2023-06-12 epoch 1800_g0 could not be preprocessed
# 2023-09-08 16:20:01,990 ceciestunepipe.pipeline.searchbout INFO     Will search for bouts through all session z_c5o30_23, 2023-06-12
# 2023-09-08 16:20:01,990 ceciestunepipe.pipeline.searchbout INFO     Will search for bouts through all session z_c5o30_23, 2023-06-12
# 2023-09-08 16:20:01,995 ceciestunepipe.pipeline.searchbout INFO     getting npy files from /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx
# 2023-09-08 16:20:01,995 ceciestunepipe.pipeline.searchbout INFO     getting npy files from /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx
# 2023-09-08 16:20:01,996 ceciestunepipe.pipeline.searchbout INFO     Found 2 files
# 2023-09-08 16:20:01,996 ceciestunepipe.pipeline.searchbout INFO     Found 2 files
# 2023-09-08 16:20:01,999 ceciestunepipe.util.sound.boutsearch INFO     Getting bouts for long file /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1752_g0/wav_mic.npy
# 2023-09-08 16:20:01,999 ceciestunepipe.util.sound.boutsearch INFO     Getting bouts for long file /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1752_g0/wav_mic.npy
# z_c5o30_23 2023-06-12 deriving bout information..
# 2023-09-08 16:20:02,000 ceciestunepipe.util.wavutil INFO     skipping wav, loading npy instead from /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1752_g0/wav_mic.npy
# 2023-09-08 16:20:02,000 ceciestunepipe.util.wavutil INFO     skipping wav, loading npy instead from /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1752_g0/wav_mic.npy
# 2023-09-08 16:20:02,001 ceciestunepipe.util.wavutil INFO     loading npy array from /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1752_g0/wav_mic.npy
# 2023-09-08 16:20:02,001 ceciestunepipe.util.wavutil INFO     loading npy array from /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1752_g0/wav_mic.npy
# 2023-09-08 16:20:02,014 ceciestunepipe.util.sound.boutsearch INFO     splitting file into 1 chunks
# 2023-09-08 16:20:02,014 ceciestunepipe.util.sound.boutsearch INFO     splitting file into 1 chunks
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2023-09-08 16:20:12,010 ceciestunepipe.util.sound.boutsearch INFO     Getting bouts for long file /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1800_g0/wav_mic.npy
# 2023-09-08 16:20:12,010 ceciestunepipe.util.sound.boutsearch INFO     Getting bouts for long file /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1800_g0/wav_mic.npy
# 2023-09-08 16:20:12,012 ceciestunepipe.util.wavutil INFO     skipping wav, loading npy instead from /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1800_g0/wav_mic.npy
# 2023-09-08 16:20:12,012 ceciestunepipe.util.wavutil INFO     skipping wav, loading npy instead from /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1800_g0/wav_mic.npy
# 2023-09-08 16:20:12,013 ceciestunepipe.util.wavutil INFO     loading npy array from /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1800_g0/wav_mic.npy
# 2023-09-08 16:20:12,013 ceciestunepipe.util.wavutil INFO     loading npy array from /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1800_g0/wav_mic.npy
# 2023-09-08 16:20:12,079 ceciestunepipe.util.sound.boutsearch INFO     splitting file into 3 chunks
# 2023-09-08 16:20:12,079 ceciestunepipe.util.sound.boutsearch INFO     splitting file into 3 chunks
#   0%|          | 0/3 [00:00<?, ?it/s]
# 2023-09-08 16:21:05,963 ceciestunepipe.pipeline.searchbout INFO     could not get rate from file /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1752_g0/wav_mic.npy
# 2023-09-08 16:21:05,963 ceciestunepipe.pipeline.searchbout INFO     could not get rate from file /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1752_g0/wav_mic.npy
# 2023-09-08 16:21:05,965 ceciestunepipe.pipeline.searchbout INFO     could not get rate from file /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1800_g0/wav_mic.npy
# 2023-09-08 16:21:05,965 ceciestunepipe.pipeline.searchbout INFO     could not get rate from file /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/sglx/1800_g0/wav_mic.npy
# 2023-09-08 16:21:05,974 ceciestunepipe.pipeline.searchbout INFO     getting spectrograms
# 2023-09-08 16:21:05,974 ceciestunepipe.pipeline.searchbout INFO     getting spectrograms
# 2023-09-08 16:21:28,598 ceciestunepipe.pipeline.searchbout INFO     saving bouts pandas to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/bouts_sglx/bout_auto.pickle
# 2023-09-08 16:21:28,598 ceciestunepipe.pipeline.searchbout INFO     saving bouts pandas to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/bouts_sglx/bout_auto.pickle
# 2023-09-08 16:21:31,892 ceciestunepipe.pipeline.searchbout INFO     saving bout detect parameters dict to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/bouts_sglx/bout_search_params.pickle
# 2023-09-08 16:21:31,892 ceciestunepipe.pipeline.searchbout INFO     saving bout detect parameters dict to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/bouts_sglx/bout_search_params.pickle
# 2023-09-08 16:21:31,894 ceciestunepipe.util.sound.boutsearch INFO     saving bout detect parameters dict to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/bouts_sglx/bout_search_params.pickle
# 2023-09-08 16:21:31,894 ceciestunepipe.util.sound.boutsearch INFO     saving bout detect parameters dict to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/bouts_sglx/bout_search_params.pickle
# 2023-09-08 16:21:31,898 ceciestunepipe.pipeline.searchbout INFO     saving bouts pandas to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/bouts_sglx/bout_auto.pickle
# 2023-09-08 16:21:31,898 ceciestunepipe.pipeline.searchbout INFO     saving bouts pandas to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/bouts_sglx/bout_auto.pickle
# 2023-09-08 16:21:35,085 ceciestunepipe.pipeline.searchbout INFO     saving bout detect parameters dict to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/bouts_sglx/bout_search_params.pickle
# 2023-09-08 16:21:35,085 ceciestunepipe.pipeline.searchbout INFO     saving bout detect parameters dict to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/bouts_sglx/bout_search_params.pickle
# 2023-09-08 16:21:35,086 ceciestunepipe.util.sound.boutsearch INFO     saving bout detect parameters dict to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/bouts_sglx/bout_search_params.pickle
# 2023-09-08 16:21:35,086 ceciestunepipe.util.sound.boutsearch INFO     saving bout detect parameters dict to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-12/bouts_sglx/bout_search_params.pickle
# 2023-09-08 16:21:35,090 root         INFO     pre-process all runs of sess 2023-06-13
# 2023-09-08 16:21:35,090 root         INFO     pre-process all runs of sess 2023-06-13
# 2023-09-08 16:21:35,092 ceciestunepipe.file.bcistructure INFO     {'folders': {'bird': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23', 'raw': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23/2023-06-13', 'sglx': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23/2023-06-13/sglx', 'kwik': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-13', 'processed': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-13/sglx', 'derived': '/mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-13/sglx', 'tmp': '/scratch/chronic_ephys/tmp', 'msort': '/scratch/chronic_ephys/z_c5o30_23/sglx/msort/2023-06-13', 'ksort': '/scratch/chronic_ephys/z_c5o30_23/sglx/ksort/2023-06-13/0', 'sort': '/mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-13/sglx/0'}, 'files': {'par': '/scratch/chronic_ephys/z_c5o30_23/sglx/ksort/2023-06-13/0/params.json', 'set': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23/2023-06-13/sglx/settings.isf', 'rig': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23/2023-06-13/sglx/rig.json', 'kwd': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-13/stream.kwd', 'kwik': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-13/sort_0/spikes.kwik', 'kwe': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-13/events.kwe', 'dat_mic': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-13/sglx/dat_mic.mat', 'dat_ap': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-13/sglx/dat_ap.mat', 'allevents': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-13/sglx/dat_all.pkl', 'wav_mic': '/mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-13/sglx/wav_mic.wav', 'mda_raw': '/scratch/chronic_ephys/z_c5o30_23/sglx/msort/2023-06-13/raw.mda', 'bin_raw': '/scratch/chronic_ephys/z_c5o30_23/sglx/ksort/2023-06-13/0/raw.bin'}}
# 2023-09-08 16:21:35,092 ceciestunepipe.file.bcistructure INFO     {'folders': {'bird': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23', 'raw': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23/2023-06-13', 'sglx': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23/2023-06-13/sglx', 'kwik': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-13', 'processed': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-13/sglx', 'derived': '/mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-13/sglx', 'tmp': '/scratch/chronic_ephys/tmp', 'msort': '/scratch/chronic_ephys/z_c5o30_23/sglx/msort/2023-06-13', 'ksort': '/scratch/chronic_ephys/z_c5o30_23/sglx/ksort/2023-06
 'kwik': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-16', 'processed': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-16/sglx', 'derived': '/mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx', 'tmp': '/scratch/chronic_ephys/tmp', 'msort': '/scratch/chronic_ephys/z_c5o30_23/sglx/msort/2023-06-16', 'ksort': '/scratch/chronic_ephys/z_c5o30_23/sglx/ksort/2023-06-16/0', 'sort': '/mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/0'}, 'files': {'par': '/scratch/chronic_ephys/z_c5o30_23/sglx/ksort/2023-06-16/0/params.json', 'set': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23/2023-06-16/sglx/settings.isf', 'rig': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23/2023-06-16/sglx/rig.json', 'kwd': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-16/stream.kwd', 'kwik': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-16/sort_0/spikes.kwik', 'kwe': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-16/events.kwe', 'dat_mic': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-16/sglx/dat_mic.mat', 'dat_ap': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-16/sglx/dat_ap.mat', 'allevents': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-16/sglx/dat_all.pkl', 'wav_mic': '/mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/wav_mic.wav', 'mda_raw': '/scratch/chronic_ephys/z_c5o30_23/sglx/msort/2023-06-16/raw.mda', 'bin_raw': '/scratch/chronic_ephys/z_c5o30_23/sglx/ksort/2023-06-16/0/raw.bin'}}
# 2023-09-08 16:48:59,610 ceciestunepipe.file.bcistructure INFO     {'folders': {'bird': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23', 'raw': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23/2023-06-16', 'sglx': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23/2023-06-16/sglx', 'kwik': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-16', 'processed': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-16/sglx', 'derived': '/mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx', 'tmp': '/scratch/chronic_ephys/tmp', 'msort': '/scratch/chronic_ephys/z_c5o30_23/sglx/msort/2023-06-16', 'ksort': '/scratch/chronic_ephys/z_c5o30_23/sglx/ksort/2023-06-16/0', 'sort': '/mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/0'}, 'files': {'par': '/scratch/chronic_ephys/z_c5o30_23/sglx/ksort/2023-06-16/0/params.json', 'set': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23/2023-06-16/sglx/settings.isf', 'rig': '/mnt/sphere/speech_bci/raw_data/z_c5o30_23/2023-06-16/sglx/rig.json', 'kwd': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-16/stream.kwd', 'kwik': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-16/sort_0/spikes.kwik', 'kwe': '/scratch/chronic_ephys/z_c5o30_23/sglx/kwik/2023-06-16/events.kwe', 'dat_mic': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-16/sglx/dat_mic.mat', 'dat_ap': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-16/sglx/dat_ap.mat', 'allevents': '/mnt/sphere/chronic_ephys/proc/z_c5o30_23/2023-06-16/sglx/dat_all.pkl', 'wav_mic': '/mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/wav_mic.wav', 'mda_raw': '/scratch/chronic_ephys/z_c5o30_23/sglx/msort/2023-06-16/raw.mda', 'bin_raw': '/scratch/chronic_ephys/z_c5o30_23/sglx/ksort/2023-06-16/0/raw.bin'}}
# 2023-09-08 16:48:59,621 root         INFO     found epochs: ['1439_g0']
# 2023-09-08 16:48:59,621 root         INFO     found epochs: ['1439_g0']
# 2023-09-08 16:48:59,623 ceciestunepipe.util.spikeextractors.preprocess INFO     PREPROCESSING sess 2023-06-16 | epoch 1439_g0
# 2023-09-08 16:48:59,623 ceciestunepipe.util.spikeextractors.preprocess INFO     PREPROCESSING sess 2023-06-16 | epoch 1439_g0
# 2023-09-08 16:48:59,623 ceciestunepipe.util.spikeextractors.preprocess INFO     getting extractors
# 2023-09-08 16:48:59,623 ceciestunepipe.util.spikeextractors.preprocess INFO     getting extractors
# 2023-09-08 16:48:59,807 ceciestunepipe.util.spikeextractors.preprocess INFO     Got sglx recordings for keys ['nidq', 'lf_0', 'ap_0']
# {'sess_par_list': ['2023-06-12', '2023-06-13', '2023-06-14', '2023-06-15', '2023-06-16'], 'mic_list': ['microphone_0'], 'adc_list': [], 'stim_list': [], 'nidq_ttl_list': [], 'sort': 0, 'software': 'sglx', 'bird': 'z_c5o30_23', 'sess': '2023-06-15'}
# z_c5o30_23 2023-06-16 sglx preprocessing session..
# preprocessing..
# 2023-09-08 16:48:59,807 ceciestunepipe.util.spikeextractors.preprocess INFO     Got sglx recordings for keys ['nidq', 'lf_0', 'ap_0']
# 2023-09-08 16:48:59,810 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting microphone channel(s) ['microphone_0']
# 2023-09-08 16:48:59,810 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting microphone channel(s) ['microphone_0']
# /mnt/cube/lo/envs/spikesort/lib/python3.8/site-packages/spikeextractors/extraction_tools.py:877: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if isinstance(start_frame, (float, np.float)):
# /mnt/cube/lo/envs/spikesort/lib/python3.8/site-packages/spikeextractors/extraction_tools.py:883: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if isinstance(end_frame, (float, np.float)):
# 2023-09-08 16:48:59,813 ceciestunepipe.util.wavutil INFO     sampling rate 40000
# 2023-09-08 16:48:59,813 ceciestunepipe.util.wavutil INFO     sampling rate 40000
# 2023-09-08 16:48:59,814 ceciestunepipe.util.wavutil INFO     saving (1, 254819414)-shaped array as wav in /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/1439_g0/wav_mic.wav
# 2023-09-08 16:48:59,814 ceciestunepipe.util.wavutil INFO     saving (1, 254819414)-shaped array as wav in /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/1439_g0/wav_mic.wav
# 2023-09-08 16:48:59,825 ceciestunepipe.util.wavutil INFO     Not saving the file as wav, going straight to numpy + dict
# 2023-09-08 16:48:59,825 ceciestunepipe.util.wavutil INFO     Not saving the file as wav, going straight to numpy + dict
# 2023-09-08 16:48:59,827 ceciestunepipe.util.wavutil INFO     saving (1, 254819414)-shaped array as npy in /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/1439_g0/wav_mic.npy
# 2023-09-08 16:48:59,827 ceciestunepipe.util.wavutil INFO     saving (1, 254819414)-shaped array as npy in /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/1439_g0/wav_mic.npy
# 2023-09-08 16:48:59,828 ceciestunepipe.util.wavutil INFO     saving (254819414, 1)-shaped array as npy in /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/1439_g0/wav_mic.npy
# 2023-09-08 16:48:59,828 ceciestunepipe.util.wavutil INFO     saving (254819414, 1)-shaped array as npy in /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/1439_g0/wav_mic.npy
# 2023-09-08 16:49:16,018 ceciestunepipe.util.wavutil INFO     Saving meta of npy array to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/1439_g0/wav_mic-npy_meta.json
# 2023-09-08 16:49:16,018 ceciestunepipe.util.wavutil INFO     Saving meta of npy array to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/1439_g0/wav_mic-npy_meta.json
# 2023-09-08 16:49:16,023 ceciestunepipe.util.wavutil INFO     Saving meta of npy array to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/1439_g0/wav_mic-npy_meta.pickle
# 2023-09-08 16:49:16,023 ceciestunepipe.util.wavutil INFO     Saving meta of npy array to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/1439_g0/wav_mic-npy_meta.pickle
# 2023-09-08 16:49:16,026 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting adc channel(s) []
# 2023-09-08 16:49:16,026 ceciestunepipe.util.spikeextractors.preprocess INFO     Getting adc channel(s) []
# /mnt/cube/lo/envs/spikesort/lib/python3.8/site-packages/spikeextractors/extraction_tools.py:877: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if isinstance(start_frame, (float, np.float)):
# /mnt/cube/lo/envs/spikesort/lib/python3.8/site-packages/spikeextractors/extraction_tools.py:883: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if isinstance(end_frame, (float, np.float)):
# /mnt/cube/tsmcpher/code/ceciestunepipe/tsm/preproc_sglx.py:45: UserWarning: Error in epoch 1439_g0
#   warnings.warn('Error in epoch {}'.format(epoch), UserWarning)
# 2023-09-08 16:49:16,027 root         INFO     <function format_exc at 0x7f36b5868280>
# 2023-09-08 16:49:16,027 root         INFO     <function format_exc at 0x7f36b5868280>
# 2023-09-08 16:49:16,028 root         INFO     index 0 is out of bounds for axis 0 with size 0
# 2023-09-08 16:49:16,028 root         INFO     index 0 is out of bounds for axis 0 with size 0
# 2023-09-08 16:49:16,029 root         INFO     Session 2023-06-16 epoch 1439_g0 could not be preprocessed
# 2023-09-08 16:49:16,029 root         INFO     Session 2023-06-16 epoch 1439_g0 could not be preprocessed
# 2023-09-08 16:49:16,140 ceciestunepipe.pipeline.searchbout INFO     Will search for bouts through all session z_c5o30_23, 2023-06-16
# 2023-09-08 16:49:16,140 ceciestunepipe.pipeline.searchbout INFO     Will search for bouts through all session z_c5o30_23, 2023-06-16
# 2023-09-08 16:49:16,144 ceciestunepipe.pipeline.searchbout INFO     getting npy files from /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx
# 2023-09-08 16:49:16,144 ceciestunepipe.pipeline.searchbout INFO     getting npy files from /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx
# 2023-09-08 16:49:16,145 ceciestunepipe.pipeline.searchbout INFO     Found 1 files
# 2023-09-08 16:49:16,145 ceciestunepipe.pipeline.searchbout INFO     Found 1 files
# 2023-09-08 16:49:16,146 ceciestunepipe.util.sound.boutsearch INFO     Getting bouts for long file /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/1439_g0/wav_mic.npy
# 2023-09-08 16:49:16,146 ceciestunepipe.util.sound.boutsearch INFO     Getting bouts for long file /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/1439_g0/wav_mic.npy
# z_c5o30_23 2023-06-16 deriving bout information..
# 2023-09-08 16:49:16,147 ceciestunepipe.util.wavutil INFO     skipping wav, loading npy instead from /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/1439_g0/wav_mic.npy
# 2023-09-08 16:49:16,147 ceciestunepipe.util.wavutil INFO     skipping wav, loading npy instead from /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/1439_g0/wav_mic.npy
# 2023-09-08 16:49:16,148 ceciestunepipe.util.wavutil INFO     loading npy array from /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/1439_g0/wav_mic.npy
# 2023-09-08 16:49:16,148 ceciestunepipe.util.wavutil INFO     loading npy array from /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/1439_g0/wav_mic.npy
# 2023-09-08 16:49:16,243 ceciestunepipe.util.sound.boutsearch INFO     splitting file into 6 chunks
# 2023-09-08 16:49:16,243 ceciestunepipe.util.sound.boutsearch INFO     splitting file into 6 chunks
#   0%|          | 0/6 [00:00<?, ?it/s]
# 2023-09-08 16:50:32,745 ceciestunepipe.pipeline.searchbout INFO     could not get rate from file /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/1439_g0/wav_mic.npy
# 2023-09-08 16:50:32,745 ceciestunepipe.pipeline.searchbout INFO     could not get rate from file /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/sglx/1439_g0/wav_mic.npy
# 2023-09-08 16:50:32,749 ceciestunepipe.pipeline.searchbout INFO     getting spectrograms
# 2023-09-08 16:50:32,749 ceciestunepipe.pipeline.searchbout INFO     getting spectrograms
# 2023-09-08 16:50:54,210 ceciestunepipe.pipeline.searchbout INFO     saving bouts pandas to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/bouts_sglx/bout_auto.pickle
# 2023-09-08 16:50:54,210 ceciestunepipe.pipeline.searchbout INFO     saving bouts pandas to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/bouts_sglx/bout_auto.pickle
# 2023-09-08 16:50:57,465 ceciestunepipe.pipeline.searchbout INFO     saving bout detect parameters dict to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/bouts_sglx/bout_search_params.pickle
# 2023-09-08 16:50:57,465 ceciestunepipe.pipeline.searchbout INFO     saving bout detect parameters dict to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/bouts_sglx/bout_search_params.pickle
# 2023-09-08 16:50:57,467 ceciestunepipe.util.sound.boutsearch INFO     saving bout detect parameters dict to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/bouts_sglx/bout_search_params.pickle
# 2023-09-08 16:50:57,467 ceciestunepipe.util.sound.boutsearch INFO     saving bout detect parameters dict to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/bouts_sglx/bout_search_params.pickle
# 2023-09-08 16:50:57,544 ceciestunepipe.pipeline.searchbout INFO     saving bouts pandas to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/bouts_sglx/bout_auto.pickle
# 2023-09-08 16:50:57,544 ceciestunepipe.pipeline.searchbout INFO     saving bouts pandas to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/bouts_sglx/bout_auto.pickle
# 2023-09-08 16:51:00,953 ceciestunepipe.pipeline.searchbout INFO     saving bout detect parameters dict to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/bouts_sglx/bout_search_params.pickle
# 2023-09-08 16:51:00,953 ceciestunepipe.pipeline.searchbout INFO     saving bout detect parameters dict to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/bouts_sglx/bout_search_params.pickle
# 2023-09-08 16:51:00,955 ceciestunepipe.util.sound.boutsearch INFO     saving bout detect parameters dict to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/bouts_sglx/bout_search_params.pickle
# 2023-09-08 16:51:00,955 ceciestunepipe.util.sound.boutsearch INFO     saving bout detect parameters dict to /mnt/sphere/chronic_ephys/der/z_c5o30_23/2023-06-16/bouts_sglx/bout_search_params.pickle
# z_c5o30_23 2023-06-17 session param matches: 0
# z_c5o30_23 2023-06-18 session param matches: 0
# z_c5o30_23 2023-06-19 session param matches: 0
# z_c5o30_23 2023-06-20 session param matches: 0
# z_c5o30_23 2023-06-21 session param matches: 0
# CPU times: user 20min 26s, sys: 7min 34s, total: 28min
# Wall time: 31min 9s
